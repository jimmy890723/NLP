# %%
import requests
from bs4 import BeautifulSoup

infos = []
intro = []
res = []

for page in range(1, 8000):
    url = 'https://movies.yahoo.com.tw/movieinfo_main/' + str(page)
    print(url)
    
    r = requests.get(url)
    soup = BeautifulSoup(r.text)
    
    if soup.find('title').text == 'Yahoo奇摩電影':
        continue
    
    info = {}
    for d in soup.find_all('div', class_="movie_intro_info_r"):

        info['名稱'] = d.find('h1').text.replace(' ', '').replace('\n', '')

        category = d.find('div', class_="level_name_box")
        category_item = category.find_all('a',class_="gabtn")
        tmp_item = str("")
        for item in category_item:
            tmp_item += item.text.replace(' ', '').replace('\n', '') + '.'
        info['分類'] = tmp_item
        
        info['上映日期'] = d.find('span').text.replace('上映日期：', '')
        
    intr = {}
    intr['劇情介紹'] = soup.find('span', id='story').text.replace(' ', '').replace('\n', '')
    
    infos.append(info)
    intro.append(intr)
    
for i, j in list(zip(infos, intro)):
    #print(i)
    res.append(dict(list(i.items()) + list(j.items())))

res
# Out:
# https://movies.yahoo.com.tw/movieinfo_main/1
# https://movies.yahoo.com.tw/movieinfo_main/2
# https://movies.yahoo.com.tw/movieinfo_main/3
# https://movies.yahoo.com.tw/movieinfo_main/4
# https://movies.yahoo.com.tw/movieinfo_main/5
# https://movies.yahoo.com.tw/movieinfo_main/6
# https://movies.yahoo.com.tw/movieinfo_main/7
# https://movies.yahoo.com.tw/movieinfo_main/8
# https://movies.yahoo.com.tw/movieinfo_main/9
# https://movies.yahoo.com.tw/movieinfo_main/10
# https://movies.yahoo.com.tw/movieinfo_main/11
# https://movies.yahoo.com.tw/movieinfo_main/12
# https://movies.yahoo.com.tw/movieinfo_main/13
# https://movies.yahoo.com.tw/movieinfo_main/14
# https://movies.yahoo.com.tw/movieinfo_main/15
# https://movies.yahoo.com.tw/movieinfo_main/16
# https://movies.yahoo.com.tw/movieinfo_main/17
# https://movies.yahoo.com.tw/movieinfo_main/18
# https://movies.yahoo.com.tw/movieinfo_main/19
# https://movies.yahoo.com.tw/movieinfo_main/20
# https://movies.yahoo.com.tw/movieinfo_main/21
# ...

# %%
#利用 DF 存取 / 另存成 CSV

import pandas as pd

df = pd.DataFrame(res)
df.to_csv('HW#2.csv', encoding='utf_8_sig')

df
# Out:
#             名稱               分類        上映日期  \
# 0         一世狂野     劇情.犯罪.歷史/傳記.  2001-10-12
# 1         玩命關頭  動作.劇情.犯罪.懸疑/驚悚.  2001-10-13
# 2         戰雲密佈  動作.犯罪.懸疑/驚悚.戰爭.  2001-10-13
# 3        騎士風雲錄        動作.冒險.喜劇.  2001-10-19
# 4         金法尤物              喜劇.  2001-10-19
# ...        ...              ...         ...
# 6509    今夜血肉燦爛        恐怖.懸疑/驚悚.  2018-04-27
# 6510      全員死刑           劇情.犯罪.  2018-03-30
# 6511   我是你轉世老爸              喜劇.  2018-04-27
# 6512  地球：奇蹟的一天             紀錄片.  2018-05-04
# 6513      高壓行動           動作.冒險.  2018-05-25
#
#                                                    劇情介紹
# 0     喬治戎格一生都在追求所謂的美國夢，也就是享受美好富裕的生活，但是他卻不願像他父親那樣一輩子都...
# 1     唐米尼杜洛托是洛城街頭賽車界的老大哥，他身邊有一群忠心耿耿的手下，他白天忙著組裝高性能跑車，...
# 2     美國空軍最高機密的隱形戰機驚傳失蹤！祕密訓練的飛行軍官傑克，被誣陷勾結恐怖組織，參與竊取戰機...
# 3     14世紀中古時期的社會階級分明，出身卑微的平民不論如何努力和奮鬥，都無法跨越階級制度而翻身致...
# 4     在【歡樂谷】、【危險性遊戲】挑大樑的瑞絲薇斯朋飾演【金法尤物】中飽受眾人歧視的金髮美女，因為...
# ...                                                 ...
# ...
